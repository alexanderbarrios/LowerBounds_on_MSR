# %%
load('definitions.sage')

# %% [markdown]
# The following code verifies that $\alpha_T, \beta_T, \gamma_T$ are the invariants $c_4,c_6,\Delta$, respectively, of $E_{T}$. The code also verifies that $\delta_{T,u_T}$ is as claimed in Table 2.

# %%
print(E2(a,b,d).c4() == S(alp2(a,b,d)))
print(E2(a,b,d).c6() == S(bet2(a,b,d)))
print(E2(a,b,d).discriminant() == S(gam2(a,b,d)))
print(S(delta2_1(a,b,d)) == S(256*delta2(a,b,d)))
print(S(delta2_2(a,b,d)) == S(4*delta2(a,b,d)))
print(S(delta2_4(a,b,d)) == S(1/64*delta2(a,b,d)))
print(E3(c^3*d^2*e,b).c4() == S(alp3(c,d,e,b)))
print(E3(c^3*d^2*e,b).c6() == S(bet3(c,d,e,b)))
print(E3(c^3*d^2*e,b).discriminant() == S(gam3(c,d,e,b)))
print(S(delta3_c2d(c,d,e,b)) == S(delta3(c,d,e,b)))
print(E4(c^2*d,b).c4() == S(alp4(c,d,b)))
print(E4(c^2*d,b).c6() == S(bet4(c,d,b)))
print(E4(c^2*d,b).discriminant() == S(gam4(c,d,b)))
print(S(delta4_c(c,d,b)) == S(2*delta4(c,d,b)))
print(S(delta4_2c(c,d,b)) == S(1/16*delta4(c,d,b)))
print(E5(a,b).c4() == S(alp5(a,b)))
print(E5(a,b).c6() == S(bet5(a,b)))
print(E5(a,b).discriminant() == S(gam5(a,b)))
print(S(delta5_1(a,b)) == S(delta5(a,b)))
print(E6(a,b).c4() == S(alp6(a,b)))
print(E6(a,b).c6() == S(bet6(a,b)))
print(E6(a,b).discriminant() == S(gam6(a,b)))
print(S(delta6_1(a,b)) == S(delta6(a,b)))
print(S(delta6_2(a,b)) == S(1/8*delta6(a,b)))
print(E7(a,b).c4() == S(alp7(a,b)))
print(E7(a,b).c6() == S(bet7(a,b)))
print(E7(a,b).discriminant() == S(gam7(a,b)))
print(S(delta7_1(a,b)) == S(delta7(a,b)))
print(E8(a,b).c4() == S(alp8(a,b)))
print(E8(a,b).c6() == S(bet8(a,b)))
print(E8(a,b).discriminant() == S(gam8(a,b)))
print(S(delta8_1(a,b)) == S(delta8(a,b)))
print(S(delta8_2(a,b)) == S(1/8*delta8(a,b)))
print(E9(a,b).c4() == S(alp9(a,b)))
print(E9(a,b).c6() == S(bet9(a,b)))
print(E9(a,b).discriminant() == S(gam9(a,b)))
print(S(delta9_1(a,b)) == S(delta9(a,b)))
print(E10(a,b).c4() == S(alp10(a,b)))
print(E10(a,b).c6() == S(bet10(a,b)))
print(E10(a,b).discriminant() == S(gam10(a,b)))
print(S(delta10_1(a,b)) == S(delta10(a,b)))
print(S(delta10_2(a,b)) == S(1/4*delta10(a,b)))
print(E12(a,b).c4() == S(alp12(a,b)))
print(E12(a,b).c6() == S(bet12(a,b)))
print(E12(a,b).discriminant() == S(gam12(a,b)))
print(S(delta12_1(a,b)) == S(delta12(a,b)))
print(S(delta12_2(a,b)) == S(1/8*delta12(a,b)))
print(E22(a,b,d).c4() == S(alp22(a,b,d)))
print(E22(a,b,d).c6() == S(bet22(a,b,d)))
print(E22(a,b,d).discriminant() == S(gam22(a,b,d)))
print(S(delta22_1(a,b,d)) == S(64*delta22(a,b,d)))
print(S(delta22_2(a,b,d)) == S(delta22(a,b,d)))
print(E24(a,b).c4() == S(alp24(a,b)))
print(E24(a,b).c6() == S(bet24(a,b)))
print(E24(a,b).discriminant() == S(gam24(a,b)))
print(S(delta24_1(a,b)) == S(8*delta24(a,b)))
print(S(delta24_2(a,b)) == S(1/2*delta24(a,b)))
print(S(delta24_4(a,b)) == S(1/32*delta24(a,b)))
print(E26(a,b).c4() == S(alp26(a,b)))
print(E26(a,b).c6() == S(bet26(a,b)))
print(E26(a,b).discriminant() == S(gam26(a,b)))
print(S(delta26_1(a,b)) == S(delta26(a,b)))
print(S(delta26_4(a,b)) == S(1/8*delta26(a,b)))
print(S(delta26_16(a,b)) == S(1/512*delta26(a,b)))
print(E28(a,b).c4() == S(alp28(a,b)))
print(E28(a,b).c6() == S(bet28(a,b)))
print(E28(a,b).discriminant() == S(gam28(a,b)))
print(S(delta28_1(a,b)) == S(2*delta28(a,b)))
print(S(delta28_16(a,b)) == S(1/128*delta28(a,b)))
print(S(delta28_64(a,b)) == S(1/4096*delta28(a,b)))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# The following code verifies Lemma 3.1.

# %%
print(S(alp2(a,b,d))==S(a^(m2/3)*alp2(1,1,b^2*d/a^2)))
print(S(bet2(a,b,d))==S(a^(m2/2)*bet2(1,1,b^2*d/a^2)))
print(S(delta2_1(a,b,d))==S(a^(m2/l2)*delta2_1(1,1,b^2*d/a^2)))
print(S(delta2_2(a,b,d))==S(a^(m2/l2)*delta2_2(1,1,b^2*d/a^2)))
print(S(delta2_4(a,b,d))==S(a^(m2/l2)*delta2_4(1,1,b^2*d/a^2)))
print(S(alp3(c,d,e,b))==S((c^3*d^2*e)^(m3/3)*alp3(1,1,1,b/(c^3*d^2*e))))
print(S(bet3(c,d,e,b))==S((c^3*d^2*e)^(m3/2)*bet3(1,1,1,b/(c^3*d^2*e))))
print(S(delta3_c2d(c,d,e,b))==S((c*d*e)^(m3/l3)*delta3_c2d(1,1,1,b/(c^3*d^2*e))))
print(S(alp4(c,d,b))==S((c^2*d)^(m4/3)*alp4(1,1,b/(c^2*d))))
print(S(bet4(c,d,b))==S((c^2*d)^(m4/2)*bet4(1,1,b/(c^2*d))))
print(S(delta4_c(c,d,b))==S((c*d)^(m4/l4)*delta4_c(1,1,b/(c^2*d))))
print(S(delta4_2c(c,d,b))==S((c*d)^(m4/l4)*delta4_2c(1,1,b/(c^2*d))))
print(S(alp5(a,b))==S(a^(m5/3)*alp5(1,b/a)))
print(S(bet5(a,b))==S(a^(m5/2)*bet5(1,b/a)))
print(S(delta5_1(a,b))==S(a^(m5/l5)*delta5_1(1,b/a)))
print(S(alp6(a,b))==S(a^(m6/3)*alp6(1,b/a)))
print(S(bet6(a,b))==S(a^(m6/2)*bet6(1,b/a)))
print(S(delta6_1(a,b))==S(a^(m6/l6)*delta6_1(1,b/a)))
print(S(delta6_2(a,b))==S(a^(m6/l6)*delta6_2(1,b/a)))
print(S(alp7(a,b))==S(a^(m7/3)*alp7(1,b/a)))
print(S(bet7(a,b))==S(a^(m7/2)*bet7(1,b/a)))
print(S(delta7_1(a,b))==S(a^(m7/l7)*delta7_1(1,b/a)))
print(S(alp8(a,b))==S(a^(m8/3)*alp8(1,b/a)))
print(S(bet8(a,b))==S(a^(m8/2)*bet8(1,b/a)))
print(S(delta8_1(a,b))==S(a^(m8/l8)*delta8_1(1,b/a)))
print(S(delta8_2(a,b))==S(a^(m8/l8)*delta8_2(1,b/a)))
print(S(alp9(a,b))==S(a^(m9/3)*alp9(1,b/a)))
print(S(bet9(a,b))==S(a^(m9/2)*bet9(1,b/a)))
print(S(delta9_1(a,b))==S(a^(m9/l9)*delta9_1(1,b/a)))
print(S(alp10(a,b))==S(a^(m10/3)*alp10(1,b/a)))
print(S(bet10(a,b))==S(a^(m10/2)*bet10(1,b/a)))
print(S(delta10_1(a,b))==S(a^(m10/l10)*delta10_1(1,b/a)))
print(S(delta10_2(a,b))==S(a^(m10/l10)*delta10_2(1,b/a)))
print(S(alp12(a,b))==S(a^(m12/3)*alp12(1,b/a)))
print(S(bet12(a,b))==S(a^(m12/2)*bet12(1,b/a)))
print(S(delta12_1(a,b))==S(a^(m12/l12)*delta12_1(1,b/a)))
print(S(delta12_2(a,b))==S(a^(m12/l12)*delta12_2(1,b/a)))
print(S(alp22(a,b,d))==S((a*d)^(m22/3)*alp22(1,b/a,1)))
print(S(bet22(a,b,d))==S((a*d)^(m22/2)*bet22(1,b/a,1)))
print(S(delta22_1(a,b,d))==S((a*d)^(m22/l22)*delta22_1(1,b/a,1)))
print(S(delta22_2(a,b,d))==S((a*d)^(m22/l22)*delta22_2(1,b/a,1)))
print(S(alp24(a,b))==S(a^(m24/3)*alp24(1,b/a)))
print(S(bet24(a,b))==S(a^(m24/2)*bet24(1,b/a)))
print(S(delta24_1(a,b))==S(a^(m24/l24)*delta24_1(1,b/a)))
print(S(delta24_2(a,b))==S(a^(m24/l24)*delta24_2(1,b/a)))
print(S(delta24_4(a,b))==S(a^(m24/l24)*delta24_4(1,b/a)))
print(S(alp26(a,b))==S(a^(m26/3)*alp26(1,b/a)))
print(S(bet26(a,b))==S(a^(m26/2)*bet26(1,b/a)))
print(S(delta26_1(a,b))==S(a^(m26/l26)*delta26_1(1,b/a)))
print(S(delta26_4(a,b))==S(a^(m26/l26)*delta26_4(1,b/a)))
print(S(delta26_16(a,b))==S(a^(m26/l26)*delta26_16(1,b/a)))
print(S(alp28(a,b))==S(a^(m28/3)*alp28(1,b/a)))
print(S(bet28(a,b))==S(a^(m28/2)*bet28(1,b/a)))
print(S(delta28_1(a,b))==S(a^(m28/l28)*delta28_1(1,b/a)))
print(S(delta28_16(a,b))==S(a^(m28/l28)*delta28_16(1,b/a)))
print(S(delta28_64(a,b))==S(a^(m28/l28)*delta28_64(1,b/a)))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
